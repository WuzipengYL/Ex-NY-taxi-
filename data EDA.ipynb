# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('2015年GBDT输入数据集csv版_各网格数量.csv')

# %%
data
# Out:
#       month  week  hour  weather  temperature  grid1  grid2  grid3  grid4  \
# 0         1     4     0        1           -2    322    171    254    410
# 1         1     4     1        1           -2    426    296    312    426
# 2         1     4     2        1           -2    415    225    249    385
# 3         1     4     3        1           -3    315    175    199    454
# 4         1     4     4        1           -3    159    109    122    264
# ...     ...   ...   ...      ...          ...    ...    ...    ...    ...
# 8755     12     4    19        1            7    329    182    341    219
# 8756     12     4    20        1            7    339    185    397    248
# 8757     12     4    21        1            7    365    168    351    246
# 8758     12     4    22        1            6    288    175    261    245
# 8759     12     4    23        1            6    204     89    227    245
#
#       grid5  ...  grid28  grid29  grid30  grid31  grid32  grid33  grid34  \
# ...

# %%
import spacetimeformer

# %%
help(spacetimeformer)
# Out:
# Help on package spacetimeformer:
#
# NAME
#     spacetimeformer
#
# PACKAGE CONTENTS
#     callbacks
#     data (package)
#     eval_stats
#     forecaster
#     linear_model (package)
#     lr_scheduler (package)
#     lstm_model (package)
#     lstnet_model (package)
#     mtgnn_model (package)
#     plot
#     spacetimeformer_model (package)
#     time2vec
#     train
#
# FILE
#     c:\users\administrator\documents\spacetimeformer\spacetimeformer\__init__.py

# %%
from spacetimeformer import spacetimeformer_model

# %%
help(spacetimeformer_model)
# Out:
# Help on package spacetimeformer.spacetimeformer_model in spacetimeformer:
#
# NAME
#     spacetimeformer.spacetimeformer_model
#
# PACKAGE CONTENTS
#     nn (package)
#     spacetimeformer_model
#     utils (package)
#
# FILE
#     c:\users\administrator\documents\spacetimeformer\spacetimeformer\spacetimeformer_model\__init__.py
